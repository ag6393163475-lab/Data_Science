# %% [markdown]
# <a href="https://colab.research.google.com/github/ag6393163475-lab/Data_Science/blob/main/lect03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fun_name(parameters):
  #body of the function

# %%
def add_numbers(num1, num2):
    return num1 + num2

# Example usage:
result = add_numbers(5, 7)
print(result)
# Out:
# 12

# %%
#lambda function
x=lambda a:2*a
print(x(2))
# Out:
# 4

# %%
st =""
print(len(st))
st="anshika"
st1=st.upper()
print(st1)
# Out:
# 0
# ANSHIKA

# %%
#remove spaces.            strip(),lstrip(),rstrip()
#split text.               split()
#join text.                join()
#replce text               replace()
#change case.              lower(),upper(),title()
#find text                 find() find index(-1 if not found)
#check text.               startswith(),endswith()
#count values.             count()
#length                    len()
#sort chairs               sorted()

# %%
st=""

print(len(st))

st="purnima"
n=st.upper()
print(n)


st.split()
st1="BEGFJHEWGIB"
st1=st1.lower()


print(st1)
st2="purnima raj"
str3=st2.capitalize()


print(str3)
str4="vcugdhfckj vtvsak"
str4.title()
# Out:
# 0
# PURNIMA
# begfjhewgib
# Purnima raj
# 'Vcugdhfckj Vtvsak'

# %%
first_name='anshika '
second_name='gupta'
#strip
first_name=first_name.strip()
second_name=second_name.strip()
# str2=first_name+second_name
str2=first_name+' '+second_name
print(str2)
# Out:
# anshika gupta

# %%
a="today"
b=" weather"
c="is Good"
a=a.strip()
b=b.strip()
c=c.strip()
st1=a.capitalize()
st2=b.lstrip()
st3=c.replace("Good","bad")



st=st1+' '+st2+' '+st3
print(st)
st4=st.find("bad")
print(st4)
# Out:
# Today weather is bad
# 17

# %%
s="hello world"
# print(s[6:11])
print(s[:5])
# Out:
# hello
